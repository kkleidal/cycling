# %%
import pandas as pd

activities_df = pd.read_csv('/Users/kkleidal/Downloads/export_54176660/activities.csv')
activities_df
# Out:
#       Activity ID              Activity Date                    Activity Name  \
# 0      3286314520   Apr 11, 2020, 8:01:26 PM    Pine Banks Park: Skyline Loop
# 1      3290789022   Apr 12, 2020, 6:46:54 PM                   Train Stations
# 2      3309376207   Apr 16, 2020, 9:50:25 PM                         Cemetery
# 3      3313847191  Apr 17, 2020, 10:56:11 PM                     Melrose Loop
# 4      3323270602   Apr 19, 2020, 4:35:30 PM                       Fells Hike
# ...           ...                        ...                              ...
# 1054  14955446257   Jun 29, 2025, 2:08:16 PM                      Gravel Ride
# 1055  14961184940  Jun 30, 2025, 10:58:52 AM                           Warmup
# 1056  14961597702  Jun 30, 2025, 11:16:11 AM                 Day A Resistance
# 1057  14978529733   Jul 1, 2025, 10:26:41 PM  Zwift - Sugar Cookie in Watopia
# 1058  14982926194   Jul 2, 2025, 11:26:16 AM                 Day B Resistance
#
# ...

# %%
from datetime import datetime


rides = activities_df[(activities_df['Activity Type'] == 'Ride') | (activities_df['Activity Type'] == 'Virtual Ride')]
rides['Activity Date'] = pd.to_datetime(rides['Activity Date'], format='%b %d, %Y, %I:%M:%S %p')
rides = rides[rides['Activity Date'] >= datetime(2025, 2, 25)]
rides = rides[rides['Activity Gear'] == 'Gravel - Giant Revolt']
rides['Distance'] = rides['Distance'].astype('float') / 1.60934
rides['Distance'].sum()
# Out:
# np.float64(663.5142356493967)
